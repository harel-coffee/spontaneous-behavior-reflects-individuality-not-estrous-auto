# %% [markdown]
# imports and data upload
# -----------

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.simplefilter('ignore')
import os
# %matplotlib inline
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.preprocessing import OneHotEncoder
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.tools.tools import pinv_extended  
from statsmodels.stats.anova import anova_lm
from tqdm.auto import tqdm

# %%
# upload data
cpath = os.getcwd() #assumes mean_df_females is in the same path as the notebook
mean_df = pd.read_csv(cpath+'/mean_df_female.csv')

# %% [markdown]
# # -----------------------------------------------------------------------
# # ANALYSIS
# # -----------------------------------------------------------------------

# %%
# plot/colors definitions
data_loc=cpath+'/figs/'
try:
    os.mkdir(data_loc)
except FileExistsError:
    # directory already exists
    pass

plt.style.use("seaborn-paper")
cmap2= ['#EC6D52' ,'#EC6D52','#977EDA','#977EDA','#5BA6E6','#5BA6E6']

# %% [markdown]
# ## GLM

# %%
# load and prepare data
df_data = mean_df.copy()
data = df_data.groupby(by = ['mouse', 'group','rep','syllable']).mean()['usage'].reset_index()
data = pd.pivot_table(data, values='usage', index=['group','rep', 'mouse'], columns=['syllable']).reset_index().fillna(0)
y = data.drop(['group','rep','mouse'], axis=1).to_numpy()
y_log = np.log(y + 1e-6)
y = (y_log - y_log.mean(axis=0, keepdims=True)) / y_log.std(axis=0, keepdims=True)

# %%
# run GLM
indv_encoder = OneHotEncoder(sparse=False).fit_transform(data.mouse.to_numpy().reshape(-1, 1))
phase_encoder = OneHotEncoder(sparse=False).fit_transform(data.group.to_numpy().reshape(-1, 1))
x = np.concatenate((phase_encoder,indv_encoder), axis=1)
lr = ElasticNet(alpha=0.01)
lr.fit(x, y)
# Out:
# ElasticNet(alpha=0.01)

# %%
# plot weights for phase and individual identity
fig, ax = plt.subplots()
fig.set_size_inches(5,5)
plt.imshow(lr.coef_, cmap='RdBu_r', vmin=-2, vmax=2)
plt.title('Model weights')
ax = plt.gca()
rect = plt.Rectangle((-0.5, -1.5), phase_encoder.shape[1], 1, facecolor='red', alpha=1, label='Estrous phase')
ax.add_patch(rect)
rect = plt.Rectangle((phase_encoder.shape[1]-0.5, -1.5), indv_encoder.shape[1], 1, facecolor='blue', alpha=1, label='indv_identity')
ax.add_patch(rect)
plt.axvline(phase_encoder.shape[1] - 0.5, c='k', ls='--', lw=1)
plt.ylim(-1.5, y.shape[1] - 0.5)
plt.colorbar()
plt.legend(frameon=False, loc='upper left', bbox_to_anchor=(1.25, 1))
fig.savefig(data_loc + 'GLM_coefficients.pdf', bbox_inches='tight')

# %% [markdown]
# ## compare multiple models

# %%
#load and prepare data
df_data = mean_df.copy()
data = df_data.groupby(by = ['mouse', 'group','rep','syllable']).mean()['usage'].reset_index()
data = pd.pivot_table(data, values='usage', index=['group','rep', 'mouse'], columns=['syllable']).reset_index().fillna(0)

y = data.drop(['group','rep','mouse'], axis=1).to_numpy()
y_log = np.log(y + 1e-6)
y = (y_log - y_log.mean(axis=0, keepdims=True)) / y_log.std(axis=0, keepdims=True)
df = pd.DataFrame()
df['indv'] = data.mouse
df['phase'] = data.group
syll=mean_df.syllable.unique()

# %%
## for addition (no interaction)
ip = []
formula = 'syll ~ C(indv) + C(phase)'
for i in range(len(syll)):
    df['syll']=y[:,i]
    model = ols(formula, data=df)
    res=model.fit_regularized(method='elastic_net',alpha=0.01)
    pinv_wexog,_ = pinv_extended(model.wexog)
    normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
    summary = sm.regression.linear_model.OLSResults(model,res.params,normalized_cov_params)
    ip.append(summary.rsquared)

# %%
## for additiona and interactions per syllable
ip_intr = []
formula = 'syll ~ C(indv) + C(phase) + C(indv):C(phase)'
for i in range(len(syll)):
    df['syll']=y[:,i]
    model = ols(formula, data=df)
    res=model.fit_regularized(method='elastic_net',alpha=0.01)
    pinv_wexog,_ = pinv_extended(model.wexog)
    normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
    summary = sm.regression.linear_model.OLSResults(model,res.params,normalized_cov_params)
    ip_intr.append(summary.rsquared)

# %%
## for individual identity alone
indv = []
formula = 'syll ~ C(indv)'
for i in range(len(syll)):
    df['syll']=y[:,i]
    model = ols(formula, data=df)
    res=model.fit_regularized(method='elastic_net',alpha=0.01)
    pinv_wexog,_ = pinv_extended(model.wexog)
    normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
    summary = sm.regression.linear_model.OLSResults(model,res.params,normalized_cov_params)
    indv.append(summary.rsquared)

# %%
## for shuffeled individual labels
a=data.mouse
formula = 'syll ~ C(new_indv)'
indv_shuff = []
it=100
for i in tqdm(range(len(syll))):
    temp_indv=[]
    df['syll']=y[:,i]
    for j in range(it):
        df['new_indv'] = np.random.permutation(a)
        model = ols(formula, data=df)
        res=model.fit_regularized(method='elastic_net',alpha=0.01)
        pinv_wexog,_ = pinv_extended(model.wexog)
        normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
        summary = sm.regression.linear_model.OLSResults(model,res.params,normalized_cov_params)
        temp_indv.append(summary.rsquared)
    indv_shuff.append(np.mean(temp_indv))
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]

# %%
## for phase alone
df['indv'] = data.mouse
df['phase'] = data.group
ph = []
formula = 'syll ~ C(phase)'

for i in range(len(syll)):
    df['syll']=y[:,i]
    model = ols(formula, data=df)
    res=model.fit_regularized(method='elastic_net',alpha=0.01)
    pinv_wexog,_ = pinv_extended(model.wexog)
    normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
    summary = sm.regression.linear_model.OLSResults(model,res.params,normalized_cov_params)
    ph.append(summary.rsquared)

# %%
## for shuffeled phase labels
formula = 'syll ~ C(new_phase)'
phase_shuff = []
it=100
for i in tqdm(range(len(syll))):
    temp_phase=[]
    df['syll']=y[:,i]
    for j in range(it):
        df['new_phase'] = data.groupby('mouse')['group'].transform(np.random.permutation)
        model = ols(formula, data=df)
        res=model.fit_regularized(method='elastic_net',alpha=0.01)
        pinv_wexog,_ = pinv_extended(model.wexog)
        normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
        summary = sm.regression.linear_model.OLSResults(model,res.params,normalized_cov_params)
        temp_phase.append(summary.rsquared)
    phase_shuff.append(np.mean(temp_phase))
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]

# %%
# create dataframe for plotting
r2 = np.concatenate((np.array(ip_intr),
                      np.array(ip),
                      np.array(ph),
                      np.array(phase_shuff),
                      np.array(indv),
                      np.array(indv_shuff)
                    ))
models = np.concatenate((len(np.array(ip_intr)) * ['indv+phase+inter'],
                         len(np.array(ip)) * ['indv_phase'],
                         len(np.array(ph)) * ['phase'],
                         len(np.array(phase_shuff)) * ['phase_shuff'],
                         len(np.array(indv)) * ['indv'],
                         len(np.array(indv_shuff)) * ['indv_shuff']
                        ))
lsyll = list(syll)*6
data = {'r2': list(r2), 
        'models': list(models),
        'syll':list(lsyll)}

# %%
# plot
fig, ax = plt.subplots()
fig.set_size_inches(5,5)
ax = sns.pointplot(x="models",y="r2",data=data,errorbar=('se'),join=False, 
                   order=['phase','phase_shuff','indv+phase+inter','indv_phase','indv','indv_shuff'], palette = cmap2)
plt.legend(frameon=False, loc='upper left', bbox_to_anchor=(1.25, 1))
ax.set_title('LGM model performance R2')
fig.savefig(data_loc +'GLM_r2.pdf', bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'LGM model performance R2')

# %% [markdown]
# ## statistically compare models

# %%
df_data = mean_df.copy()
data = df_data.groupby(by = ['mouse', 'group','rep','syllable']).mean()['usage'].reset_index()
data = pd.pivot_table(data, values='usage', index=['group','rep', 'mouse'], columns=['syllable']).reset_index().fillna(0)

# %%
y = data.drop(['group','rep','mouse'], axis=1).to_numpy()
y_log = np.log(y + 1e-6)
y = (y_log - y_log.mean(axis=0, keepdims=True)) / y_log.std(axis=0, keepdims=True)
df = pd.DataFrame()
df['indv'] = data.mouse
df['phase'] = data.group
syll=mean_df.syllable.unique()

# %%
# models
f1 = 'syll ~ C(indv)'
f2 = 'syll ~ C(indv) + C(phase)'
f3 = 'syll ~ C(indv) + C(phase) + C(indv):C(phase)'
r1,r2,r3=[],[],[]
fig, ax = plt.subplots()
fig.set_size_inches(10,10)

for i in tqdm(range(len(syll))):
    df['syll']=y[:,i]
    print('syllable: ',+i)
    model1 = ols(f1, data=df)
    res1=model1.fit_regularized(method='elastic_net',alpha=0.01)
    pinv_wexog,_ = pinv_extended(model1.wexog)
    normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
    summary1 = sm.regression.linear_model.OLSResults(model1,res1.params,normalized_cov_params)
    
    model2 = ols(f2, data=df)
    res2=model2.fit_regularized(method='elastic_net',alpha=0.01)
    pinv_wexog,_ = pinv_extended(model2.wexog)
    normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
    summary2 = sm.regression.linear_model.OLSResults(model2,res2.params,normalized_cov_params)
    anovaResults = anova_lm(summary1,summary2)
    
    model3 = ols(f3, data=df)
    res3=model3.fit_regularized(method='elastic_net',alpha=0.01)
    pinv_wexog,_ = pinv_extended(model3.wexog)
    normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
    summary3 = sm.regression.linear_model.OLSResults(model3,res3.params,normalized_cov_params)

    r1.append(summary1.rsquared)
    r2.append(summary2.rsquared)
    r3.append(summary3.rsquared)
    # compare models
    anovaResults = anova_lm(summary1,summary2)
    print(anovaResults)
    anovaResults = anova_lm(summary1,summary3)
    print(anovaResults)
    anovaResults = anova_lm(summary2,summary3)
    print(anovaResults)
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
# syllable:  0
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  127.564820      0.0       NaN       NaN       NaN
# 1     181.0  122.731147      3.0  4.833673  2.376182  0.071549
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  127.56482      0.0       NaN       NaN       NaN
# 1     146.0  116.12895     38.0  11.43587  0.378354  0.999599
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     181.0  122.731147      0.0       NaN       NaN       NaN
# 1     146.0  116.128950     35.0  6.602197  0.237155  0.999998
# syllable:  1
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  70.383093      0.0       NaN       NaN       NaN
# 1     181.0  70.311290      3.0  0.071803  0.061614  0.979934
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  70.383093      0.0       NaN       NaN     NaN
# 1     146.0  69.284159     38.0  1.098934  0.060941     1.0
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  70.311290      0.0       NaN       NaN     NaN
# 1     146.0  69.284159     35.0  1.027131  0.061841     1.0
# syllable:  2
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  112.167058      0.0       NaN       NaN       NaN
# 1     181.0  107.121668      3.0  5.045389  2.841677  0.039249
#    df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     184.0  112.167058      0.0      NaN       NaN       NaN
# 1     146.0  104.768877     38.0  7.39818  0.271308  0.999993
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  107.121668      0.0       NaN       NaN     NaN
# 1     146.0  104.768877     35.0  2.352791  0.093678     1.0
# syllable:  3
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  103.244516      0.0       NaN       NaN       NaN
# 1     181.0  101.637427      3.0  1.607089  0.953989  0.415757
#    df_resid         ssr  df_diff   ss_diff        F  Pr(>F)
# 0     184.0  103.244516      0.0       NaN      NaN     NaN
# 1     146.0   98.857784     38.0  4.386732  0.17049     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  101.637427      0.0       NaN       NaN     NaN
# 1     146.0   98.857784     35.0  2.779643  0.117291     1.0
# syllable:  4
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  144.477837      0.0       NaN       NaN       NaN
# 1     181.0  139.519307      3.0  4.958531  2.144253  0.096256
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  144.477837      0.0        NaN       NaN       NaN
# 1     146.0  129.060573     38.0  15.417264  0.458969  0.996852
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     181.0  139.519307      0.0        NaN       NaN       NaN
# 1     146.0  129.060573     35.0  10.458734  0.338042  0.999816
# syllable:  5
#    df_resid         ssr  df_diff   ss_diff         F   Pr(>F)
# 0     184.0  105.340066      0.0       NaN       NaN      NaN
# 1     181.0  102.747784      3.0  2.592282  1.522184  0.21031
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  105.340066      0.0       NaN       NaN     NaN
# 1     146.0  102.291521     38.0  3.048545  0.114504     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  102.747784      0.0       NaN       NaN     NaN
# 1     146.0  102.291521     35.0  0.456263  0.018606     1.0
# syllable:  6
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  124.246926      0.0       NaN       NaN       NaN
# 1     181.0  121.656541      3.0  2.590385  1.284654  0.281107
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  124.246926      0.0       NaN       NaN     NaN
# 1     146.0  120.217737     38.0  4.029189  0.128771     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  121.656541      0.0       NaN       NaN     NaN
# 1     146.0  120.217737     35.0  1.438803  0.049925     1.0
# syllable:  7
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  112.624938      0.0       NaN       NaN       NaN
# 1     181.0  112.513141      3.0  0.111796  0.059949  0.980712
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  112.624938      0.0       NaN       NaN     NaN
# 1     146.0  110.376763     38.0  2.248175  0.078257     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  112.513141      0.0       NaN       NaN     NaN
# 1     146.0  110.376763     35.0  2.136378  0.080739     1.0
# syllable:  8
#    df_resid       ssr  df_diff  ss_diff         F    Pr(>F)
# 0     184.0  79.71421      0.0      NaN       NaN       NaN
# 1     181.0  78.75339      3.0  0.96082  0.736088  0.531762
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  79.714210      0.0       NaN       NaN     NaN
# 1     146.0  77.262222     38.0  2.451988  0.121933     1.0
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  78.753390      0.0       NaN       NaN     NaN
# 1     146.0  77.262222     35.0  1.491169  0.080509     1.0
# syllable:  9
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  112.164013      0.0       NaN       NaN       NaN
# 1     181.0  110.890717      3.0  1.273297  0.692774  0.557563
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  112.164013      0.0       NaN       NaN     NaN
# 1     146.0  106.679034     38.0  5.484979  0.197545     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  110.890717      0.0       NaN       NaN     NaN
# 1     146.0  106.679034     35.0  4.211682  0.164688     1.0
# syllable:  10
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  132.290392      0.0       NaN       NaN       NaN
# 1     181.0  127.755187      3.0  4.535205  2.141784  0.096559
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  132.290392      0.0       NaN       NaN       NaN
# 1     146.0  122.455965     38.0  9.834427  0.308559  0.999965
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  127.755187      0.0       NaN       NaN     NaN
# 1     146.0  122.455965     35.0  5.299222  0.180517     1.0
# syllable:  11
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  130.532140      0.0       NaN       NaN       NaN
# 1     181.0  129.270363      3.0  1.261777  0.588899  0.623025
#    df_resid         ssr  df_diff   ss_diff        F  Pr(>F)
# 0     184.0  130.532140      0.0       NaN      NaN     NaN
# 1     146.0  128.847641     38.0  1.684499  0.05023     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  129.270363      0.0       NaN       NaN     NaN
# 1     146.0  128.847641     35.0  0.422721  0.013686     1.0
# syllable:  12
#    df_resid         ssr  df_diff   ss_diff         F   Pr(>F)
# 0     184.0  145.770995      0.0       NaN       NaN      NaN
# 1     181.0  143.255651      3.0  2.515345  1.059359  0.36773
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  145.770995      0.0       NaN       NaN     NaN
# 1     146.0  139.167541     38.0  6.603455  0.182307     1.0
#    df_resid         ssr  df_diff  ss_diff         F  Pr(>F)
# 0     181.0  143.255651      0.0      NaN       NaN     NaN
# 1     146.0  139.167541     35.0  4.08811  0.122538     1.0
# syllable:  13
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  92.409965      0.0       NaN       NaN       NaN
# 1     181.0  89.068379      3.0  3.341586  2.263531  0.082659
#    df_resid        ssr  df_diff  ss_diff         F    Pr(>F)
# 0     184.0  92.409965      0.0      NaN       NaN       NaN
# 1     146.0  85.403665     38.0   7.0063  0.315197  0.999955
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  89.068379      0.0       NaN       NaN     NaN
# 1     146.0  85.403665     35.0  3.664714  0.178998     1.0
# syllable:  14
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  170.047945      0.0       NaN       NaN       NaN
# 1     181.0  165.449678      3.0  4.598267  1.676817  0.173603
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  170.047945      0.0       NaN       NaN     NaN
# 1     146.0  162.993606     38.0  7.054339  0.166286     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  165.449678      0.0       NaN       NaN     NaN
# 1     146.0  162.993606     35.0  2.456072  0.062857     1.0
# syllable:  15
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  116.848381      0.0       NaN       NaN       NaN
# 1     181.0  115.572946      3.0  1.275436  0.665824  0.574068
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  116.848381      0.0       NaN       NaN       NaN
# 1     146.0  110.191548     38.0  6.656833  0.232107  0.999999
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  115.572946      0.0       NaN       NaN     NaN
# 1     146.0  110.191548     35.0  5.381397  0.203719     1.0
# syllable:  16
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  97.743816      0.0       NaN       NaN       NaN
# 1     181.0  96.052573      3.0  1.691243  1.062317  0.366454
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  97.743816      0.0       NaN       NaN     NaN
# 1     146.0  93.109885     38.0  4.633931  0.191215     1.0
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  96.052573      0.0       NaN       NaN     NaN
# 1     146.0  93.109885     35.0  2.942688  0.131836     1.0
# syllable:  17
#    df_resid        ssr  df_diff  ss_diff         F    Pr(>F)
# 0     184.0  99.430498      0.0      NaN       NaN       NaN
# 1     181.0  98.112758      3.0  1.31774  0.810329  0.489653
#    df_resid        ssr  df_diff  ss_diff         F  Pr(>F)
# 0     184.0  99.430498      0.0      NaN       NaN     NaN
# 1     146.0  96.796428     38.0  2.63407  0.104553     1.0
#    df_resid        ssr  df_diff  ss_diff         F  Pr(>F)
# 0     181.0  98.112758      0.0      NaN       NaN     NaN
# 1     146.0  96.796428     35.0  1.31633  0.056727     1.0
# syllable:  18
#    df_resid         ssr  df_diff   ss_diff         F   Pr(>F)
# 0     184.0  106.158865      0.0       NaN       NaN      NaN
# 1     181.0  105.510641      3.0  0.648224  0.370669  0.77426
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  106.158865      0.0       NaN       NaN     NaN
# 1     146.0  101.233223     38.0  4.925642  0.186943     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  105.510641      0.0       NaN       NaN     NaN
# 1     146.0  101.233223     35.0  4.277417  0.176256     1.0
# syllable:  19
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  117.206089      0.0       NaN       NaN       NaN
# 1     181.0  113.488246      3.0  3.717842  1.976503  0.119115
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  117.206089      0.0        NaN       NaN       NaN
# 1     146.0  106.646922     38.0  10.559167  0.380409  0.999573
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     181.0  113.488246      0.0       NaN       NaN       NaN
# 1     146.0  106.646922     35.0  6.841325  0.267594  0.999988
# syllable:  20
#    df_resid         ssr  df_diff  ss_diff        F    Pr(>F)
# 0     184.0  112.533699      0.0      NaN      NaN       NaN
# 1     181.0  112.008830      3.0  0.52487  0.28272  0.837832
#    df_resid         ssr  df_diff   ss_diff        F  Pr(>F)
# 0     184.0  112.533699      0.0       NaN      NaN     NaN
# 1     146.0  109.424772     38.0  3.108927  0.10916     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  112.008830      0.0       NaN       NaN     NaN
# 1     146.0  109.424772     35.0  2.584057  0.098508     1.0
# syllable:  21
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  118.789570      0.0       NaN       NaN       NaN
# 1     181.0  114.437313      3.0  4.352257  2.294585  0.079438
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  118.789570      0.0        NaN       NaN       NaN
# 1     146.0  103.510613     38.0  15.278956  0.567124  0.978385
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     181.0  114.437313      0.0        NaN       NaN       NaN
# 1     146.0  103.510613     35.0  10.926699  0.440341  0.997112
# syllable:  22
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  148.016560      0.0       NaN       NaN       NaN
# 1     181.0  143.325598      3.0  4.690963  1.974675  0.119391
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  148.016560      0.0       NaN       NaN     NaN
# 1     146.0  140.661984     38.0  7.354577  0.200886     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  143.325598      0.0       NaN       NaN     NaN
# 1     146.0  140.661984     35.0  2.663614  0.078991     1.0
# syllable:  23
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  139.061734      0.0       NaN       NaN       NaN
# 1     181.0  134.371439      3.0  4.690295  2.105962  0.101065
#    df_resid         ssr  df_diff  ss_diff         F  Pr(>F)
# 0     184.0  139.061734      0.0      NaN       NaN     NaN
# 1     146.0  132.393884     38.0  6.66785  0.193503     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  134.371439      0.0       NaN       NaN     NaN
# 1     146.0  132.393884     35.0  1.977556  0.062308     1.0
# syllable:  24
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  113.941888      0.0       NaN       NaN       NaN
# 1     181.0  113.799805      3.0  0.142083  0.075328  0.973208
#    df_resid         ssr  df_diff   ss_diff        F  Pr(>F)
# 0     184.0  113.941888      0.0       NaN      NaN     NaN
# 1     146.0  108.775608     38.0  5.166279  0.18248     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  113.799805      0.0       NaN       NaN     NaN
# 1     146.0  108.775608     35.0  5.024196  0.192673     1.0
# syllable:  25
#    df_resid         ssr  df_diff   ss_diff         F   Pr(>F)
# 0     184.0  154.219404      0.0       NaN       NaN      NaN
# 1     181.0  150.306176      3.0  3.913228  1.570781  0.19805
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  154.219404      0.0        NaN       NaN       NaN
# 1     146.0  133.126552     38.0  21.092852  0.608751  0.962147
#    df_resid         ssr  df_diff    ss_diff         F   Pr(>F)
# 0     181.0  150.306176      0.0        NaN       NaN      NaN
# 1     146.0  133.126552     35.0  17.179623  0.538312  0.98289
# syllable:  26
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  97.217049      0.0       NaN       NaN       NaN
# 1     181.0  95.671547      3.0  1.545501  0.974639  0.405943
#    df_resid        ssr  df_diff  ss_diff        F  Pr(>F)
# 0     184.0  97.217049      0.0      NaN      NaN     NaN
# 1     146.0  92.526328     38.0  4.69072  0.19478     1.0
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  95.671547      0.0       NaN       NaN     NaN
# 1     146.0  92.526328     35.0  3.145219  0.141798     1.0
# syllable:  27
#    df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     184.0  102.843689      0.0      NaN       NaN       NaN
# 1     181.0  102.751089      3.0   0.0926  0.054373  0.983256
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  102.843689      0.0       NaN       NaN     NaN
# 1     146.0   99.425800     38.0  3.417889  0.132077     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  102.751089      0.0       NaN       NaN     NaN
# 1     146.0   99.425800     35.0  3.325289  0.139513     1.0
# syllable:  28
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  68.164411      0.0       NaN       NaN     NaN
# 1     181.0  70.745864      3.0 -2.581453 -2.201509     1.0
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  68.164411      0.0       NaN       NaN     NaN
# 1     146.0  70.065925     38.0 -1.901514 -0.104271     1.0
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  70.745864      0.0       NaN       NaN     NaN
# 1     146.0  70.065925     35.0  0.679939  0.040481     1.0
# syllable:  29
#    df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     184.0  137.787585      0.0       NaN      NaN       NaN
# 1     181.0  134.020513      3.0  3.767072  1.69586  0.169528
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  137.787585      0.0        NaN       NaN       NaN
# 1     146.0  123.338151     38.0  14.449434  0.450114  0.997411
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     181.0  134.020513      0.0        NaN       NaN       NaN
# 1     146.0  123.338151     35.0  10.682362  0.361289  0.999618
# syllable:  30
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  89.550556      0.0       NaN       NaN       NaN
# 1     181.0  89.302460      3.0  0.248096  0.167615  0.918115
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  89.550556      0.0       NaN       NaN     NaN
# 1     146.0  88.686297     38.0  0.864259  0.037442     1.0
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  89.302460      0.0       NaN       NaN     NaN
# 1     146.0  88.686297     35.0  0.616163  0.028982     1.0
# syllable:  31
#    df_resid         ssr  df_diff   ss_diff         F   Pr(>F)
# 0     184.0  138.864199      0.0       NaN       NaN      NaN
# 1     181.0  134.661150      3.0  4.203049  1.883126  0.13403
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  138.864199      0.0        NaN       NaN       NaN
# 1     146.0  125.029418     38.0  13.834781  0.425137  0.998563
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     181.0  134.661150      0.0       NaN       NaN       NaN
# 1     146.0  125.029418     35.0  9.631732  0.321349  0.999897
# syllable:  32
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  148.086292      0.0       NaN       NaN       NaN
# 1     181.0  140.229128      3.0  7.857164  3.380531  0.019482
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  148.086292      0.0       NaN       NaN       NaN
# 1     146.0  137.218952     38.0  10.86734  0.304284  0.999971
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  140.229128      0.0       NaN       NaN     NaN
# 1     146.0  137.218952     35.0  3.010176  0.091509     1.0
# syllable:  33
#    df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     184.0  125.628539      0.0       NaN      NaN       NaN
# 1     181.0  125.588948      3.0  0.039591  0.01902  0.996423
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  125.628539      0.0       NaN       NaN     NaN
# 1     146.0  122.720752     38.0  2.907788  0.091036     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  125.588948      0.0       NaN       NaN     NaN
# 1     146.0  122.720752     35.0  2.868197  0.097494     1.0
# syllable:  34
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  125.772280      0.0       NaN       NaN       NaN
# 1     181.0  124.237638      3.0  1.534642  0.745266  0.526411
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  125.772280      0.0       NaN       NaN     NaN
# 1     146.0  119.663986     38.0  6.108293  0.196122     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  124.237638      0.0       NaN       NaN     NaN
# 1     146.0  119.663986     35.0  4.573651  0.159435     1.0
# syllable:  35
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  174.819045      0.0        NaN       NaN       NaN
# 1     181.0  164.659863      3.0  10.159181  3.722445  0.012472
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  174.819045      0.0       NaN       NaN       NaN
# 1     146.0  164.265455     38.0  10.55359  0.246844  0.999998
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  164.659863      0.0       NaN       NaN     NaN
# 1     146.0  164.265455     35.0  0.394408  0.010016     1.0
# syllable:  36
#    df_resid         ssr  df_diff   ss_diff         F   Pr(>F)
# 0     184.0  125.195764      0.0       NaN       NaN      NaN
# 1     181.0  123.065208      3.0  2.130557  1.044516  0.37419
#    df_resid         ssr  df_diff    ss_diff        F    Pr(>F)
# 0     184.0  125.195764      0.0        NaN      NaN       NaN
# 1     146.0  101.840010     38.0  23.355754  0.88114  0.667531
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     181.0  123.065208      0.0        NaN       NaN       NaN
# 1     146.0  101.840010     35.0  21.225197  0.869397  0.677945
# syllable:  37
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  132.153998      0.0       NaN       NaN       NaN
# 1     181.0  131.672310      3.0  0.481688  0.220713  0.881928
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  132.153998      0.0        NaN       NaN       NaN
# 1     146.0  116.302023     38.0  15.851975  0.523679  0.989076
#    df_resid         ssr  df_diff    ss_diff         F   Pr(>F)
# 0     181.0  131.672310      0.0        NaN       NaN      NaN
# 1     146.0  116.302023     35.0  15.370287  0.551289  0.97929
# syllable:  38
#    df_resid         ssr  df_diff   ss_diff         F   Pr(>F)
# 0     184.0  145.996076      0.0       NaN       NaN      NaN
# 1     181.0  143.680822      3.0  2.315255  0.972204  0.40709
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  145.996076      0.0       NaN       NaN     NaN
# 1     146.0  141.138271     38.0  4.857805  0.132241     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  143.680822      0.0       NaN       NaN     NaN
# 1     146.0  141.138271     35.0  2.542551  0.075147     1.0
# syllable:  39
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  114.235864      0.0       NaN       NaN       NaN
# 1     181.0  114.013466      3.0  0.222397  0.117688  0.949634
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  114.235864      0.0       NaN       NaN     NaN
# 1     146.0  111.358216     38.0  2.877648  0.099285     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  114.013466      0.0       NaN       NaN     NaN
# 1     146.0  111.358216     35.0  2.655251  0.099464     1.0
# syllable:  40
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  78.365741      0.0       NaN       NaN       NaN
# 1     181.0  78.016776      3.0  0.348965  0.269868  0.847068
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  78.365741      0.0       NaN       NaN     NaN
# 1     146.0  75.401055     38.0  2.964686  0.151067     1.0
#    df_resid        ssr  df_diff   ss_diff        F  Pr(>F)
# 0     181.0  78.016776      0.0       NaN      NaN     NaN
# 1     146.0  75.401055     35.0  2.615721  0.14471     1.0
# syllable:  41
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  188.325607      0.0       NaN       NaN       NaN
# 1     181.0  187.522005      3.0  0.803602  0.258551  0.855168
#    df_resid         ssr  df_diff  ss_diff         F  Pr(>F)
# 0     184.0  188.325607      0.0      NaN       NaN     NaN
# 1     146.0  179.371027     38.0  8.95458  0.191806     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  187.522005      0.0       NaN       NaN     NaN
# 1     146.0  179.371027     35.0  8.150978  0.189558     1.0
# syllable:  42
#    df_resid        ssr  df_diff  ss_diff       F  Pr(>F)
# 0     184.0  88.659967      0.0      NaN     NaN     NaN
# 1     181.0  88.840937      3.0 -0.18097 -0.1229     1.0
#    df_resid        ssr  df_diff   ss_diff        F  Pr(>F)
# 0     184.0  88.659967      0.0       NaN      NaN     NaN
# 1     146.0  86.737443     38.0  1.922524  0.08516     1.0
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  88.840937      0.0       NaN       NaN     NaN
# 1     146.0  86.737443     35.0  2.103494  0.101162     1.0
# syllable:  43
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  119.330065      0.0       NaN       NaN       NaN
# 1     181.0  119.219628      3.0  0.110436  0.055888  0.982574
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  119.330065      0.0       NaN       NaN     NaN
# 1     146.0  118.078788     38.0  1.251277  0.040715     1.0
#    df_resid         ssr  df_diff  ss_diff         F  Pr(>F)
# 0     181.0  119.219628      0.0      NaN       NaN     NaN
# 1     146.0  118.078788     35.0  1.14084  0.040303     1.0
# syllable:  44
#    df_resid         ssr  df_diff       ss_diff             F  Pr(>F)
# 0     184.0  120.672225      0.0           NaN           NaN     NaN
# 1     181.0  120.672225      3.0  1.359325e-09  6.796312e-10     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  120.672225      0.0       NaN       NaN     NaN
# 1     146.0  120.295086     38.0  0.377139  0.012045     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  120.672225      0.0       NaN       NaN     NaN
# 1     146.0  120.295086     35.0  0.377139  0.013078     1.0
# syllable:  45
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  121.364344      0.0       NaN       NaN       NaN
# 1     181.0  120.779824      3.0  0.584521  0.291987  0.831154
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     184.0  121.364344      0.0       NaN       NaN     NaN
# 1     146.0  120.281736     38.0  1.082609  0.034581     1.0
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  120.779824      0.0       NaN       NaN     NaN
# 1     146.0  120.281736     35.0  0.498088  0.017274     1.0
# syllable:  46
#    df_resid        ssr  df_diff       ss_diff             F  Pr(>F)
# 0     184.0  110.90657      0.0           NaN           NaN     NaN
# 1     181.0  110.90657      3.0  3.979039e-13  2.164603e-13     1.0
#    df_resid         ssr  df_diff    ss_diff        F    Pr(>F)
# 0     184.0  110.906570      0.0        NaN      NaN       NaN
# 1     146.0   95.368539     38.0  15.538031  0.62598  0.953371
#    df_resid         ssr  df_diff    ss_diff         F   Pr(>F)
# 0     181.0  110.906570      0.0        NaN       NaN      NaN
# 1     146.0   95.368539     35.0  15.538031  0.679635  0.90893
# syllable:  47
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  121.122886      0.0       NaN       NaN       NaN
# 1     181.0  119.787227      3.0  1.335659  0.672732  0.569805
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  121.122886      0.0       NaN       NaN       NaN
# 1     146.0  114.265241     38.0  6.857645  0.230584  0.999999
#    df_resid         ssr  df_diff   ss_diff         F  Pr(>F)
# 0     181.0  119.787227      0.0       NaN       NaN     NaN
# 1     146.0  114.265241     35.0  5.521986  0.201589     1.0
# syllable:  48
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     184.0  126.060658      0.0       NaN       NaN       NaN
# 1     181.0  123.874725      3.0  2.185933  1.064661  0.365445
#    df_resid         ssr  df_diff    ss_diff         F    Pr(>F)
# 0     184.0  126.060658      0.0        NaN       NaN       NaN
# 1     146.0  115.437095     38.0  10.623563  0.353585  0.999817
#    df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     181.0  123.874725      0.0      NaN       NaN       NaN
# 1     146.0  115.437095     35.0  8.43763  0.304902  0.999944
